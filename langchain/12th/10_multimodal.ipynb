# %%
# # # 최신 버전이 필요합니다 (멀티 모달을 위해)
! pip install -U langchain openai chromadb langchain-experimental 
! pip install "unstructured[all-docs]" pillow pydantic lxml pillow matplotlib chromadb tiktoken
# Out:
# Requirement already satisfied: langchain in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (0.2.11)
# Requirement already satisfied: openai in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (1.37.0)
# Collecting openai
#   Downloading openai-1.37.1-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: chromadb in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (0.5.5)
# Requirement already satisfied: langchain-experimental in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (0.0.63)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.23 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from langchain) (0.2.24)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from langchain) (0.1.85)
# Requirement already satisfied: numpy<2,>=1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from langchain) (8.3.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: build>=1.0.3 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (0.111.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.1)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (1.18.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (1.63.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (30.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (3.10.6)
# Requirement already satisfied: langchain-community<0.3.0,>=0.2.6 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from langchain-experimental) (0.2.10)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: idna>=2.8 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: packaging>=19.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: colorama in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.4)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.9)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from fastapi>=0.95.2->chromadb) (2.2.0)
# Requirement already satisfied: certifi in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain-experimental) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from langchain-core<0.3.0,>=0.2.23->langchain) (1.33)
# Requirement already satisfied: coloredlogs in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (70.3.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.23.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->langchain-experimental) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->langchain-experimental) (0.9.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.23->langchain) (3.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.18.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->langchain-experimental) (1.0.0)
# Downloading openai-1.37.1-py3-none-any.whl (337 kB)
#    ---------------------------------------- 0.0/337.0 kB ? eta -:--:--
#    -------------- ------------------------- 122.9/337.0 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 337.0/337.0 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.37.0
#     Uninstalling openai-1.37.0:
#       Successfully uninstalled openai-1.37.0
# Successfully installed openai-1.37.1
# Requirement already satisfied: pillow in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (10.4.0)
# Requirement already satisfied: pydantic in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (2.8.2)
# Requirement already satisfied: lxml in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (5.2.2)
# Requirement already satisfied: matplotlib in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (3.9.1)
# Requirement already satisfied: chromadb in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (0.5.5)
# Requirement already satisfied: tiktoken in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (0.7.0)
# Requirement already satisfied: unstructured[all-docs] in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (0.10.19)
# Requirement already satisfied: chardet in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (5.2.0)
# Requirement already satisfied: filetype in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (0.4.27)
# Requirement already satisfied: nltk in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (3.8.1)
# Requirement already satisfied: tabulate in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (0.9.0)
# Requirement already satisfied: requests in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (4.12.3)
# Requirement already satisfied: emoji in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (2.12.1)
# Requirement already satisfied: dataclasses-json in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (2024.4.27)
# Requirement already satisfied: langdetect in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (1.0.9)
# Requirement already satisfied: numpy in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (1.26.4)
# Requirement already satisfied: msg-parser in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (1.2.0)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (0.3.12)
# Requirement already satisfied: openpyxl in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (3.1.5)
# Requirement already satisfied: pandas in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (2.2.2)
# Requirement already satisfied: pdf2image in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (1.17.0)
# Requirement already satisfied: pdfminer.six in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (20231228)
# Requirement already satisfied: python-pptx<=0.6.21 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (0.6.21)
# Requirement already satisfied: pypandoc in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (1.13)
# Requirement already satisfied: xlrd in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (2.0.1)
# Requirement already satisfied: python-docx in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (1.1.2)
# Requirement already satisfied: unstructured-inference==0.6.6 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (0.6.6)
# Requirement already satisfied: ebooklib in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (0.18)
# Requirement already satisfied: markdown in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured[all-docs]) (3.6)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]) (0.3.4)
# Requirement already satisfied: python-multipart in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]) (0.0.9)
# Requirement already satisfied: huggingface-hub in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]) (0.23.4)
# Requirement already satisfied: opencv-python!=4.7.0.68 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]) (4.10.0.84)
# Requirement already satisfied: onnx==1.14.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]) (1.14.1)
# Requirement already satisfied: onnxruntime in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]) (1.18.1)
# Requirement already satisfied: transformers>=4.25.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]) (4.42.4)
# Requirement already satisfied: rapidfuzz in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from unstructured-inference==0.6.6->unstructured[all-docs]) (3.9.4)
# Requirement already satisfied: protobuf>=3.20.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from onnx==1.14.1->unstructured-inference==0.6.6->unstructured[all-docs]) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from onnx==1.14.1->unstructured-inference==0.6.6->unstructured[all-docs]) (4.12.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from pydantic) (2.20.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: build>=1.0.3 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (0.111.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.1)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (4.66.4)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (1.63.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (30.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (8.3.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (3.10.6)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: pyproject_hooks in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: colorama in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.4)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from fastapi>=0.95.2->chromadb) (2.2.0)
# Requirement already satisfied: anyio in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from httpx>=0.27.0->chromadb) (4.4.0)
# Requirement already satisfied: certifi in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.5)
# Requirement already satisfied: idna in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.2)
# Requirement already satisfied: coloredlogs in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from onnxruntime->unstructured-inference==0.6.6->unstructured[all-docs]) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from onnxruntime->unstructured-inference==0.6.6->unstructured[all-docs]) (24.3.25)
# Requirement already satisfied: sympy in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from onnxruntime->unstructured-inference==0.6.6->unstructured[all-docs]) (1.13.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (70.3.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from python-pptx<=0.6.21->unstructured[all-docs]) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from requests->unstructured[all-docs]) (3.3.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from beautifulsoup4->unstructured[all-docs]) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from dataclasses-json->unstructured[all-docs]) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from dataclasses-json->unstructured[all-docs]) (0.9.0)
# Requirement already satisfied: olefile>=0.46 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from msg-parser->unstructured[all-docs]) (0.47)
# Requirement already satisfied: joblib in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from nltk->unstructured[all-docs]) (1.4.2)
# Requirement already satisfied: et-xmlfile in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from openpyxl->unstructured[all-docs]) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from pandas->unstructured[all-docs]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from pandas->unstructured[all-docs]) (2024.1)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from pdfminer.six->unstructured[all-docs]) (42.0.8)
# Requirement already satisfied: cffi>=1.12 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (1.16.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from huggingface-hub->unstructured-inference==0.6.6->unstructured[all-docs]) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from huggingface-hub->unstructured-inference==0.6.6->unstructured[all-docs]) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.18.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from transformers>=4.25.1->unstructured-inference==0.6.6->unstructured[all-docs]) (0.4.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[all-docs]) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from coloredlogs->onnxruntime->unstructured-inference==0.6.6->unstructured[all-docs]) (10.0)
# Requirement already satisfied: scipy in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (1.14.0)
# Requirement already satisfied: iopath in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (0.1.10)
# Requirement already satisfied: pdfplumber in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (0.11.2)
# Requirement already satisfied: torch in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (2.2.2)
# Requirement already satisfied: torchvision in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (0.17.2)
# Requirement already satisfied: effdet in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (0.4.1)
# Requirement already satisfied: pytesseract in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (0.3.10)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from sympy->onnxruntime->unstructured-inference==0.6.6->unstructured[all-docs]) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (2.22)
# Requirement already satisfied: pyreadline3 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime->unstructured-inference==0.6.6->unstructured[all-docs]) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)
# Requirement already satisfied: timm>=0.9.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (1.0.7)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (2.0.8)
# Requirement already satisfied: omegaconf>=2.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (2.3.0)
# Requirement already satisfied: networkx in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (3.3)
# Requirement already satisfied: portalocker in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (2.10.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (4.30.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (4.9.3)
# Requirement already satisfied: pywin32>=226 in c:\users\userk\desktop\langchain\langchain_me\.conda\lib\site-packages (from portalocker->iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.6.6->unstructured[all-docs]) (306)

# %%
fpath = "C:\\Users\\UserK\\Desktop\\LangChain\\langchain_me\\12_RAG\\data\\cj\\"
fname = "cj.pdf"

# %%
import os
from langchain_text_splitters import CharacterTextSplitter
from unstructured.partition.pdf import partition_pdf

# PDF에서 요소 추출


def extract_pdf_elements(path, fname):
    """
    PDF 파일에서 이미지, 테이블, 그리고 텍스트 조각을 추출합니다.
    path: 이미지(.jpg)를 저장할 파일 경로
    fname: 파일 이름
    """
    return partition_pdf(
        filename=os.path.join(path, fname),
        extract_images_in_pdf=True,  # PDF 내 이미지 추출 활성화
        infer_table_structure=True,  # 테이블 구조 추론 활성화
        chunking_strategy="by_title",  # 제목별로 텍스트 조각화
        max_characters=4000,  # 최대 문자 수
        new_after_n_chars=3800,  # 이 문자 수 이후에 새로운 조각 생성
        combine_text_under_n_chars=2000,  # 이 문자 수 이하의 텍스트는 결합
        image_output_dir_path=path,  # 이미지 출력 디렉토리 경로
    )


# 요소를 유형별로 분류


def categorize_elements(raw_pdf_elements):
    """
    PDF에서 추출된 요소를 테이블과 텍스트로 분류합니다.
    raw_pdf_elements: unstructured.documents.elements의 리스트
    """
    tables = []  # 테이블 저장 리스트
    texts = []  # 텍스트 저장 리스트
    for element in raw_pdf_elements:
        if "unstructured.documents.elements.Table" in str(type(element)):
            tables.append(str(element))  # 테이블 요소 추가
        elif "unstructured.documents.elements.CompositeElement" in str(type(element)):
            texts.append(str(element))  # 텍스트 요소 추가
    return texts, tables


# 요소 추출
raw_pdf_elements = extract_pdf_elements(fpath, fname)

# 텍스트, 테이블 추출
texts, tables = categorize_elements(raw_pdf_elements)

# 선택사항: 텍스트에 대해 특정 토큰 크기 적용
text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=4000, chunk_overlap=0  # 텍스트를 4000 토큰 크기로 분할, 중복 없음
)
joined_texts = " ".join(texts)  # 텍스트 결합
texts_4k_token = text_splitter.split_text(joined_texts)  # 분할 실행
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\pytesseract\pytesseract.py:388, in get_tesseract_version()
#     387 try:
# --> 388     output = subprocess.check_output(
#     389         [tesseract_cmd, '--version'],
#     390         stderr=subprocess.STDOUT,
#     391         env=environ,
#     392         stdin=subprocess.DEVNULL,
#     393     )
#     394 except OSError:
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다
#
# During handling of the above exception, another exception occurred:
#
# TesseractNotFoundError                    Traceback (most recent call last)
# Cell In[5], line 45
#      41     return texts, tables
#      44 # 요소 추출
# ---> 45 raw_pdf_elements = extract_pdf_elements(fpath, fname)
#      47 # 텍스트, 테이블 추출
#      48 texts, tables = categorize_elements(raw_pdf_elements)
#
# Cell In[5], line 14, in extract_pdf_elements(path, fname)
#       8 def extract_pdf_elements(path, fname):
#       9     """
#      10     PDF 파일에서 이미지, 테이블, 그리고 텍스트 조각을 추출합니다.
#      11     path: 이미지(.jpg)를 저장할 파일 경로
#      12     fname: 파일 이름
#      13     """
# ---> 14     return partition_pdf(
#      15         filename=os.path.join(path, fname),
#      16         extract_images_in_pdf=True,  # PDF 내 이미지 추출 활성화
#      17         infer_table_structure=True,  # 테이블 구조 추론 활성화
#      18         chunking_strategy="by_title",  # 제목별로 텍스트 조각화
#      19         max_characters=4000,  # 최대 문자 수
#      20         new_after_n_chars=3800,  # 이 문자 수 이후에 새로운 조각 생성
#      21         combine_text_under_n_chars=2000,  # 이 문자 수 이하의 텍스트는 결합
#      22         image_output_dir_path=path,  # 이미지 출력 디렉토리 경로
#      23     )
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\unstructured\documents\elements.py:280, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     278 @functools.wraps(func)
#     279 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 280     elements = func(*args, **kwargs)
#     281     sig = inspect.signature(func)
#     282     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\unstructured\file_utils\filetype.py:551, in add_metadata_with_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     549 @functools.wraps(func)
#     550 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 551     elements = func(*args, **kwargs)
#     552     sig = inspect.signature(func)
#     553     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\unstructured\chunking\title.py:257, in add_chunking_strategy.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     255 @functools.wraps(func)
#     256 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 257     elements = func(*args, **kwargs)
#     258     sig = inspect.signature(func)
#     259     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\unstructured\partition\pdf.py:155, in partition_pdf(filename, file, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, max_partition, min_partition, include_metadata, metadata_filename, metadata_last_modified, chunking_strategy, links, **kwargs)
#     149         languages = convert_old_ocr_languages_to_languages(ocr_languages)
#     150         logger.warning(
#     151             "The ocr_languages kwarg will be deprecated in a future version of unstructured. "
#     152             "Please use languages instead.",
#     153         )
# --> 155 return partition_pdf_or_image(
#     156     filename=filename,
#     157     file=file,
#     158     include_page_breaks=include_page_breaks,
#     159     strategy=strategy,
#     160     infer_table_structure=infer_table_structure,
#     161     languages=languages,
#     162     max_partition=max_partition,
#     163     min_partition=min_partition,
#     164     metadata_last_modified=metadata_last_modified,
#     165     **kwargs,
#     166 )
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\unstructured\partition\pdf.py:278, in partition_pdf_or_image(filename, file, is_image, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, max_partition, min_partition, metadata_last_modified, **kwargs)
#     276 with warnings.catch_warnings():
#     277     warnings.simplefilter("ignore")
# --> 278     _layout_elements = _partition_pdf_or_image_local(
#     279         filename=filename,
#     280         file=spooled_to_bytes_io_if_needed(file),
#     281         is_image=is_image,
#     282         infer_table_structure=infer_table_structure,
#     283         include_page_breaks=include_page_breaks,
#     284         languages=languages,
#     285         ocr_mode="entire_page",
#     286         metadata_last_modified=metadata_last_modified or last_modification_date,
#     287         **kwargs,
#     288     )
#     289     layout_elements = []
#     290     for el in _layout_elements:
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\unstructured\utils.py:159, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     150 if len(missing_deps) > 0:
#     151     raise ImportError(
#     152         f"Following dependencies are missing: {', '.join(missing_deps)}. "
#     153         + (
#    (...)
#     157         ),
#     158     )
# --> 159 return func(*args, **kwargs)
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\unstructured\partition\pdf.py:363, in _partition_pdf_or_image_local(filename, file, is_image, infer_table_structure, include_page_breaks, languages, ocr_mode, model_name, metadata_last_modified, **kwargs)
#     360         process_with_model_kwargs[key] = value
#     362 if file is None:
# --> 363     layout = process_file_with_model(
#     364         filename,
#     365         **process_with_model_kwargs,
#     366     )
#     367 else:
#     368     layout = process_data_with_model(
#     369         file,
#     370         **process_with_model_kwargs,
#     371     )
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\unstructured_inference\inference\layout.py:611, in process_file_with_model(filename, model_name, is_image, ocr_strategy, ocr_languages, ocr_mode, fixed_layouts, extract_tables, pdf_image_dpi, **kwargs)
#     597 else:
#     598     raise ValueError(f"Unsupported model type: {type(model)}")
#     599 layout = (
#     600     DocumentLayout.from_image_file(
#     601         filename,
#     602         detection_model=detection_model,
#     603         element_extraction_model=element_extraction_model,
#     604         ocr_strategy=ocr_strategy,
#     605         ocr_languages=ocr_languages,
#     606         ocr_mode=ocr_mode,
#     607         extract_tables=extract_tables,
#     608         **kwargs,
#     609     )
#     610     if is_image
# --> 611     else DocumentLayout.from_file(
#     612         filename,
#     613         detection_model=detection_model,
#     614         element_extraction_model=element_extraction_model,
#     615         ocr_strategy=ocr_strategy,
#     616         ocr_languages=ocr_languages,
#     617         ocr_mode=ocr_mode,
#     618         fixed_layouts=fixed_layouts,
#     619         extract_tables=extract_tables,
#     620         pdf_image_dpi=pdf_image_dpi,
#     621         **kwargs,
#     622     )
#     623 )
#     624 return layout
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\unstructured_inference\inference\layout.py:120, in DocumentLayout.from_file(cls, filename, detection_model, element_extraction_model, fixed_layouts, ocr_strategy, ocr_languages, ocr_mode, extract_tables, pdf_image_dpi, **kwargs)
#     114 for i, (image_path, layout, fixed_layout) in enumerate(
#     115     zip(image_paths, layouts, fixed_layouts),
#     116 ):
#     117     # NOTE(robinson) - In the future, maybe we detect the page number and default
#     118     # to the index if it is not detected
#     119     with Image.open(image_path) as image:
# --> 120         page = PageLayout.from_image(
#     121             image,
#     122             number=i + 1,
#     123             document_filename=filename,
#     124             detection_model=detection_model,
#     125             element_extraction_model=element_extraction_model,
#     126             layout=layout,
#     127             ocr_strategy=ocr_strategy,
#     128             ocr_languages=ocr_languages,
#     129             ocr_mode=ocr_mode,
#     130             fixed_layout=fixed_layout,
#     131             extract_tables=extract_tables,
#     132             **kwargs,
#     133         )
#     134         pages.append(page)
#     135 return cls.from_pages(pages)
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\unstructured_inference\inference\layout.py:513, in PageLayout.from_image(cls, image, image_path, document_filename, number, detection_model, element_extraction_model, layout, ocr_strategy, ocr_languages, ocr_mode, extract_tables, fixed_layout, supplement_with_ocr_elements, extract_images_in_pdf, image_output_dir_path, analysis)
#     511     return page
#     512 if fixed_layout is None:
# --> 513     page.get_elements_with_detection_model()
#     514 else:
#     515     page.elements = page.get_elements_from_layout(fixed_layout)
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\unstructured_inference\inference\layout.py:290, in PageLayout.get_elements_with_detection_model(self, inplace)
#     288 logger.info("Processing entrie page OCR with tesseract...")
#     289 try:
# --> 290     ocr_data = pytesseract.image_to_data(
#     291         self.image,
#     292         lang=self.ocr_languages,
#     293         output_type=Output.DICT,
#     294     )
#     295     ocr_layout = parse_ocr_data_tesseract(ocr_data)
#     296 except pytesseract.pytesseract.TesseractError:
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\pytesseract\pytesseract.py:521, in image_to_data(image, lang, config, nice, output_type, timeout, pandas_config)
#     507 def image_to_data(
#     508     image,
#     509     lang=None,
#    (...)
#     514     pandas_config=None,
#     515 ):
#     516     """
#     517     Returns string containing box boundaries, confidences,
#     518     and other information. Requires Tesseract 3.05+
#     519     """
# --> 521     if get_tesseract_version() < TESSERACT_MIN_VERSION:
#     522         raise TSVNotSupported()
#     524     config = f'-c tessedit_create_tsv=1 {config.strip()}'
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\pytesseract\pytesseract.py:146, in run_once.<locals>.wrapper(*args, **kwargs)
#     143 @wraps(func)
#     144 def wrapper(*args, **kwargs):
#     145     if wrapper._result is wrapper:
# --> 146         wrapper._result = func(*args, **kwargs)
#     147     return wrapper._result
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\pytesseract\pytesseract.py:395, in get_tesseract_version()
#     388     output = subprocess.check_output(
#     389         [tesseract_cmd, '--version'],
#     390         stderr=subprocess.STDOUT,
#     391         env=environ,
#     392         stdin=subprocess.DEVNULL,
#     393     )
#     394 except OSError:
# --> 395     raise TesseractNotFoundError()
#     397 raw_version = output.decode(DEFAULT_ENCODING)
#     398 str_version, *_ = raw_version.lstrip(string.printable[10:]).partition(' ')
#
# TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.

# %%
len(texts_4k_token)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 len(texts_4k_token)
#
# NameError: name 'texts_4k_token' is not defined

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# 텍스트 요소의 요약 생성


def generate_text_summaries(texts, tables, summarize_texts=False):
    """
    텍스트 요소 요약
    texts: 문자열 리스트
    tables: 문자열 리스트
    summarize_texts: 텍스트 요약 여부를 결정. True/False
    """

    # 프롬프트 설정
    prompt_text = """You are an assistant tasked with summarizing tables and text for retrieval. \
    These summaries will be embedded and used to retrieve the raw text or table elements. \
    Give a concise summary of the table or text that is well optimized for retrieval. Table or text: {element} """
    prompt = ChatPromptTemplate.from_template(prompt_text)

    # 텍스트 요약 체인
    model = ChatOpenAI(temperature=0, model="gpt-4")
    summarize_chain = {"element": lambda x: x} | prompt | model | StrOutputParser()

    # 요약을 위한 빈 리스트 초기화
    text_summaries = []
    table_summaries = []

    # 제공된 텍스트에 대해 요약이 요청되었을 경우 적용
    if texts and summarize_texts:
        text_summaries = summarize_chain.batch(texts, {"max_concurrency": 5})
    elif texts:
        text_summaries = texts

    # 제공된 테이블에 적용
    if tables:
        table_summaries = summarize_chain.batch(tables, {"max_concurrency": 5})

    return text_summaries, table_summaries


# 텍스트, 테이블 요약 가져오기
text_summaries, table_summaries = generate_text_summaries(
    texts_4k_token, tables, summarize_texts=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 45
#      40     return text_summaries, table_summaries
#      43 # 텍스트, 테이블 요약 가져오기
#      44 text_summaries, table_summaries = generate_text_summaries(
# ---> 45     texts_4k_token, tables, summarize_texts=True
#      46 )
#
# NameError: name 'texts_4k_token' is not defined

# %%
import base64
import os

from langchain_core.messages import HumanMessage


def encode_image(image_path):
    # 이미지 파일을 base64 문자열로 인코딩합니다.
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")


def image_summarize(img_base64, prompt):
    # 이미지 요약을 생성합니다.
    chat = ChatOpenAI(model="gpt-4o", max_tokens=2048)

    msg = chat.invoke(
        [
            HumanMessage(
                content=[
                    {"type": "text", "text": prompt},
                    {
                        "type": "image_url",
                        "image_url": {"url": f"data:image/jpeg;base64,{img_base64}"},
                    },
                ]
            )
        ]
    )
    return msg.content


def generate_img_summaries(path):
    """
    이미지에 대한 요약과 base64 인코딩된 문자열을 생성합니다.
    path: Unstructured에 의해 추출된 .jpg 파일 목록의 경로
    """

    # base64로 인코딩된 이미지를 저장할 리스트
    img_base64_list = []

    # 이미지 요약을 저장할 리스트
    image_summaries = []

    # 요약을 위한 프롬프트
    prompt = """You are an assistant tasked with summarizing images for retrieval. \
    These summaries will be embedded and used to retrieve the raw image. \
    Give a concise summary of the image that is well optimized for retrieval."""

    # 이미지에 적용
    for img_file in sorted(os.listdir(path)):
        if img_file.endswith(".jpg"):
            img_path = os.path.join(path, img_file)
            base64_image = encode_image(img_path)
            img_base64_list.append(base64_image)
            image_summaries.append(image_summarize(base64_image, prompt))

    return img_base64_list, image_summaries


# 이미지 요약 실행
img_base64_list, image_summaries = generate_img_summaries(fpath)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[8], line 62
#      58     return img_base64_list, image_summaries
#      61 # 이미지 요약 실행
# ---> 62 img_base64_list, image_summaries = generate_img_summaries(fpath)
#
# Cell In[8], line 56, in generate_img_summaries(path)
#      54         base64_image = encode_image(img_path)
#      55         img_base64_list.append(base64_image)
# ---> 56         image_summaries.append(image_summarize(base64_image, prompt))
#      58 return img_base64_list, image_summaries
#
# Cell In[8], line 15, in image_summarize(img_base64, prompt)
#      13 def image_summarize(img_base64, prompt):
#      14     # 이미지 요약을 생성합니다.
# ---> 15     chat = ChatOpenAI(model="gpt-4o", max_tokens=2048)
#      17     msg = chat.invoke(
#      18         [
#      19             HumanMessage(
#    (...)
#      28         ]
#      29     )
#      30     return msg.content
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\pydantic\v1\main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#     343     object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for ChatOpenAI
# __root__
#   Did not find openai_api_key, please add an environment variable `OPENAI_API_KEY` which contains it, or pass `openai_api_key` as a named parameter. (type=value_error)

# %%
len(image_summaries)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 len(image_summaries)
#
# NameError: name 'image_summaries' is not defined

# %%
import uuid

from langchain.retrievers.multi_vector import MultiVectorRetriever
from langchain.storage import InMemoryStore
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings


def create_multi_vector_retriever(
    vectorstore, text_summaries, texts, table_summaries, tables, image_summaries, images
):
    """
    요약을 색인화하지만 원본 이미지나 텍스트를 반환하는 검색기를 생성합니다.
    """

    # 저장 계층 초기화
    store = InMemoryStore()
    id_key = "doc_id"

    # 멀티 벡터 검색기 생성
    retriever = MultiVectorRetriever(
        vectorstore=vectorstore,
        docstore=store,
        id_key=id_key,
    )

    # 문서를 벡터 저장소와 문서 저장소에 추가하는 헬퍼 함수
    def add_documents(retriever, doc_summaries, doc_contents):
        doc_ids = [
            str(uuid.uuid4()) for _ in doc_contents
        ]  # 문서 내용마다 고유 ID 생성
        summary_docs = [
            Document(page_content=s, metadata={id_key: doc_ids[i]})
            for i, s in enumerate(doc_summaries)
        ]
        retriever.vectorstore.add_documents(
            summary_docs
        )  # 요약 문서를 벡터 저장소에 추가
        retriever.docstore.mset(
            list(zip(doc_ids, doc_contents))
        )  # 문서 내용을 문서 저장소에 추가

    # 텍스트, 테이블, 이미지 추가
    if text_summaries:
        add_documents(retriever, text_summaries, texts)

    if table_summaries:
        add_documents(retriever, table_summaries, tables)

    if image_summaries:
        add_documents(retriever, image_summaries, images)

    return retriever

# %%
# 요약을 색인화하기 위해 사용할 벡터 저장소
vectorstore = Chroma(
    collection_name="sample-rag-multi-modal", embedding_function=OpenAIEmbeddings()
)

# 검색기 생성
retriever_multi_vector_img = create_multi_vector_retriever(
    vectorstore,
    text_summaries,
    texts,
    table_summaries,
    tables,
    image_summaries,
    img_base64_list,
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[11], line 3
#       1 # 요약을 색인화하기 위해 사용할 벡터 저장소
#       2 vectorstore = Chroma(
# ----> 3     collection_name="sample-rag-multi-modal", embedding_function=OpenAIEmbeddings()
#       4 )
#       6 # 검색기 생성
#       7 retriever_multi_vector_img = create_multi_vector_retriever(
#       8     vectorstore,
#       9     text_summaries,
#    (...)
#      14     img_base64_list,
#      15 )
#
# File c:\Users\UserK\Desktop\LangChain\langchain_me\.conda\Lib\site-packages\pydantic\v1\main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#     343     object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for OpenAIEmbeddings
# __root__
#   Did not find openai_api_key, please add an environment variable `OPENAI_API_KEY` which contains it, or pass `openai_api_key` as a named parameter. (type=value_error)

# %%
import io
import re

from IPython.display import HTML, display
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from PIL import Image


def plt_img_base64(img_base64):
    """base64 인코딩된 문자열을 이미지로 표시"""
    # base64 문자열을 소스로 사용하는 HTML img 태그 생성
    image_html = f'<img src="data:image/jpeg;base64,{img_base64}" />'
    # HTML을 렌더링하여 이미지 표시
    display(HTML(image_html))


def looks_like_base64(sb):
    """문자열이 base64로 보이는지 확인"""
    return re.match("^[A-Za-z0-9+/]+[=]{0,2}$", sb) is not None


def is_image_data(b64data):
    """
    base64 데이터가 이미지인지 시작 부분을 보고 확인
    """
    image_signatures = {
        b"\xff\xd8\xff": "jpg",
        b"\x89\x50\x4e\x47\x0d\x0a\x1a\x0a": "png",
        b"\x47\x49\x46\x38": "gif",
        b"\x52\x49\x46\x46": "webp",
    }
    try:
        header = base64.b64decode(b64data)[:8]  # 처음 8바이트를 디코드하여 가져옴
        for sig, format in image_signatures.items():
            if header.startswith(sig):
                return True
        return False
    except Exception:
        return False


def resize_base64_image(base64_string, size=(128, 128)):
    """
    Base64 문자열로 인코딩된 이미지의 크기 조정
    """
    # Base64 문자열 디코드
    img_data = base64.b64decode(base64_string)
    img = Image.open(io.BytesIO(img_data))

    # 이미지 크기 조정
    resized_img = img.resize(size, Image.LANCZOS)

    # 조정된 이미지를 바이트 버퍼에 저장
    buffered = io.BytesIO()
    resized_img.save(buffered, format=img.format)

    # 조정된 이미지를 Base64로 인코딩
    return base64.b64encode(buffered.getvalue()).decode("utf-8")


def split_image_text_types(docs):
    """
    base64로 인코딩된 이미지와 텍스트 분리
    """
    b64_images = []
    texts = []
    for doc in docs:
        # 문서가 Document 타입인 경우 page_content 추출
        if isinstance(doc, Document):
            doc = doc.page_content
        if looks_like_base64(doc) and is_image_data(doc):
            doc = resize_base64_image(doc, size=(1300, 600))
            b64_images.append(doc)
        else:
            texts.append(doc)
    return {"images": b64_images, "texts": texts}


def img_prompt_func(data_dict):
    """
    컨텍스트를 단일 문자열로 결합
    """
    formatted_texts = "\n".join(data_dict["context"]["texts"])
    messages = []

    # 이미지가 있으면 메시지에 추가
    if data_dict["context"]["images"]:
        for image in data_dict["context"]["images"]:
            image_message = {
                "type": "image_url",
                "image_url": {"url": f"data:image/jpeg;base64,{image}"},
            }
            messages.append(image_message)

    # 분석을 위한 텍스트 추가
    text_message = {
        "type": "text",
        "text": (
            "You are financial analyst tasking with providing investment advice.\n"
            "You will be given a mixed of text, tables, and image(s) usually of charts or graphs.\n"
            "Use this information to provide investment advice related to the user question. Answer in Korean. Do NOT translate company names.\n"
            f"User-provided question: {data_dict['question']}\n\n"
            "Text and / or tables:\n"
            f"{formatted_texts}"
        ),
    }
    messages.append(text_message)
    return [HumanMessage(content=messages)]


def multi_modal_rag_chain(retriever):
    """
    멀티모달 RAG 체인
    """

    # 멀티모달 LLM
    model = ChatOpenAI(temperature=0, model="gpt-4o", max_tokens=2048)

    # RAG 파이프라인
    chain = (
        {
            "context": retriever | RunnableLambda(split_image_text_types),
            "question": RunnablePassthrough(),
        }
        | RunnableLambda(img_prompt_func)
        | model
        | StrOutputParser()
    )

    return chain


# RAG 체인 생성
chain_multimodal_rag = multi_modal_rag_chain(retriever_multi_vector_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 134
#     130     return chain
#     133 # RAG 체인 생성
# --> 134 chain_multimodal_rag = multi_modal_rag_chain(retriever_multi_vector_img)
#
# NameError: name 'retriever_multi_vector_img' is not defined

# %%
# 검색 질의 실행
query = "EV/NTM 및 NTM 매출 성장률을 기준으로 흥미로운 투자처인 기업 이름을 알려주세요. EV/NTM 멀티플과 과거를 고려하시나요?"

# 질의에 대한 문서 6개를 검색합니다.
docs = retriever_multi_vector_img.invoke(query, limit=6)

# 문서의 개수 확인
len(docs)  # 검색된 문서의 개수를 반환합니다.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       2 query = "EV/NTM 및 NTM 매출 성장률을 기준으로 흥미로운 투자처인 기업 이름을 알려주세요. EV/NTM 멀티플과 과거를 고려하시나요?"
#       4 # 질의에 대한 문서 6개를 검색합니다.
# ----> 5 docs = retriever_multi_vector_img.invoke(query, limit=6)
#       7 # 문서의 개수 확인
#       8 len(docs)  # 검색된 문서의 개수를 반환합니다.
#
# NameError: name 'retriever_multi_vector_img' is not defined

# %%
# 검색 결과 확인
query = "Mongo DB, Cloudflare, Datadog 의 EV/NTM 및 NTM rev 성장률은 얼마인가요?"
docs = retriever_multi_vector_img.invoke(query, limit=6)

# 문서의 개수 확인
len(docs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 # 검색 결과 확인
#       2 query = "Mongo DB, Cloudflare, Datadog 의 EV/NTM 및 NTM rev 성장률은 얼마인가요?"
# ----> 3 docs = retriever_multi_vector_img.invoke(query, limit=6)
#       5 # 문서의 개수 확인
#       6 len(docs)
#
# NameError: name 'retriever_multi_vector_img' is not defined
